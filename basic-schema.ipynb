# %%
print("Hello")
# Out:
# Hello

# %%
import os
from dotenv import find_dotenv,load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(
    base_url="https://api.groq.com/openai/v1",
    model="openai/gpt-oss-120b",
    api_key=os.getenv("Free_API_KEY"),
    temperature=0.0,
)

# %%
from langchain_core.messages import HumanMessage

message=[HumanMessage(content="What is the name of founder of Open ai")]

response=llm.invoke(message)
print(response.content)
# Out:
# c:\Users\pande\AppData\Local\pypoetry\Cache\virtualenvs\basic-sentiment-analysis-app-th2zNNcT-py3.11\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# OpenAI was founded by a group of entrepreneurs and researchers, including:
#
# - **Elon Musk**
# - **Sam Altman**
# - **Greg Brockman**
# - **Ilya Sutskever**
# - **John Schulman**
# - **Wojciech Zaremba**
#
# These individuals (along with a few others) launched OpenAI in December 2015. Sam Altman currently serves as the CEO.
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=6f827866-a4ef-4342-a360-396d86c713bb,id=6f827866-a4ef-4342-a360-396d86c713bb
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=6f827866-a4ef-4342-a360-396d86c713bb,id=6f827866-a4ef-4342-a360-396d86c713bb
